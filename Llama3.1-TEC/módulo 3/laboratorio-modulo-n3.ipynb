# %% [markdown]
# # Laboratorio Módulo 3: Deployment y Consumo de LLaMa 3.1 con Ollama
#
# ## Llama 3.1 - TEC de Monterrey 2025
#
# **Capacitación:** TEC de Monterrey 2025
# **Fecha:** Noviembre 2025
#
# **Objetivo:**
# Aprender a instalar y usar Ollama para ejecutar modelos LLaMa en CPU y consumir el modelo desde Python en Visual Studio Code usando la API REST. Incluye instalación de herramientas y ejercicios prácticos.
#
# ---

# %% [markdown]
# ## 0. Instalación de Herramientas
#
# ### 0.1 Instalar Visual Studio Code
#
# - Descargar Visual Studio Code desde: [https://code.visualstudio.com/](https://code.visualstudio.com/)
# - Instalar como cualquier programa en Windows o Mac.
#
# ### 0.2 Instalar Python 3.10 o superior
#
# - Descargar Python desde: [https://www.python.org/downloads/](https://www.python.org/downloads/)
# - Durante la instalación en Windows, marcar la opción **"Add Python to PATH"**.
# - En Mac, puedes usar el instalador o `brew install python`.
#
# ### 0.3 Instalar extensiones en VS Code
#
# 1. Abre VS Code.
# 2. Ve a la barra lateral izquierda (ícono de cuadrados) o presiona `Ctrl+Shift+X`.
# 3. Busca e instala:
#     - **Python** (de Microsoft)
#     - **Jupyter** (de Microsoft)
#
# ---

# %% [markdown]
# ## 1. Preparación del entorno de trabajo
#
# ### 1.1 Crear y activar un entorno virtual (opcional pero recomendado)
#
# Abre la terminal integrada en VS Code (`Ctrl+ñ` o desde menú Terminal > Nueva terminal).
#
# #### **Windows:**
# ```bash
# python -m venv venv
# .\venv\Scripts\activate
# ```
#
# #### **Mac:**
# ```bash
# python3 -m venv venv
# source venv/bin/activate
# ```
#
# ### 1.2 Instalar dependencias Python
# ```bash
# pip install jupyter requests
# ```
#
# ---

# %% [markdown]
# ## 2. Instalación y prueba de Ollama
#
# ### 2.1 Instalar Ollama
#
# - **Windows:**
#   - Descarga el instalador desde [https://ollama.ai/download](https://ollama.ai/download) y sigue las instrucciones. Puede requerir WSL2 (se instala automáticamente si es necesario).
# - **Mac:**
#   - Puedes instalar desde terminal con:
#     ```bash
#     brew install ollama
#     ```
#     O descarga el instalador desde [https://ollama.ai/download](https://ollama.ai/download).
#
# ### 2.2 Verificar la instalación
# Abre una terminal (puede ser la misma de VS Code) y ejecuta:
# ```bash
# ollama --version
# ```
#
# ---

# %% [markdown]
# ## 3. Descargar y ejecutar LLaMa 3.1 en Ollama
#
# ### 3.1 Descargar modelo
# ```bash
# ollama pull llama3
# ```
#
# ### 3.2 Probar el modelo desde la terminal
# ```bash
# ollama run llama3 "¿Qué es la inteligencia artificial?"
# ```
#
# ---

# %% [markdown]
# ## 4. Consumir Ollama desde Python usando la API REST
# > Antes de seguir, asegúrate que Ollama está corriendo (el instalador inicia el servicio automáticamente; si no, ejecuta `ollama serve`).

# %%
import requests

OLLAMA_HOST = "http://localhost:11434"

prompt = "Explica brevemente el concepto de aprendizaje profundo."
payload = {
    "model": "llama3.1",
    "prompt": prompt,
    "stream": False
}

response = requests.post(f"{OLLAMA_HOST}/api/generate", json=payload)
result = response.json()
print("Respuesta del modelo:")
print(result.get("response", "Error"))
# Out:
# Respuesta del modelo:
# El aprendizaje profundo es un tipo de inteligencia artificial que se enfoca en imitar los procesos del cerebro humano para analizar datos complejos y realizar tareas como reconocimiento de imágenes, lenguaje natural, música y más. El objetivo principal es crear modelos informáticos capaces de aprender a través de la experiencia, mejorando su desempeño con el tiempo sin necesidad de supervisión humana directa.

# %% [markdown]
# ---
#
# ### 4.2 Experimenta con diferentes parámetros

# %%
for temperature in [0.3, 0.7, 1.0]:
    payload = {
        "model": "llama3.1",
        "prompt": "Resume la importancia de los transformers en el procesamiento de lenguaje natural.",
        "temperature": temperature,
        "top_p": 0.9,
        "stream": False
    }
    response = requests.post(f"{OLLAMA_HOST}/api/generate", json=payload)
    print(f"\nTemperature={temperature}:")
    print(response.json().get("response", "Error"))
# Out:
# Temperature=0.3:
# Los **Transformers** han tenido un impacto significativo en el desarrollo del Procesamiento de Lenguaje Natural (PLN), especialmente desde su introducción en 2017 a través del artículo "Attention Is All You Need" de Vaswani et al.
#
# ### Características clave:
#
# 1.  **Atención no lineal:** Los Transformers utilizan una forma no lineal de atención, lo que les permite capturar relaciones entre palabras más lejanas dentro del texto.
# 2.  **Capacidad para aprender secuencias largas:** A diferencia de las redes recurrentes (RNN) y convolucionales (CNN), los Transformeres pueden procesar secuencias de longitud variable con eficiencia, lo que es particularmente útil en tareas como el traductor automático.
# 3.  **Capacidad para almacenar información larga plazo:** Los Transformers están diseñados para almacenar la representación semántica de una secuencia completa en su estado intermedio, mejorando así la capacidad del modelo para capturar patrones a largo plazo.
#
# ### Aplicaciones:
#
# 1.  **Traductor automático:** Los Transformeres han sido aplicados con éxito en traductores automáticos, logrando resultados que superan significativamente a los modelos anteriores.
# 2.  **Generación de texto:** Utilizan para tareas de generación de texto, como la creación de resúmenes y la redacción de textos a partir de una serie de pautas o temas dadas.
# 3.  **Clasificación de texto:** En aplicaciones de clasificación de texto, donde se necesitan identificar categorías o etiquetas para un conjunto dado de documentos, los Transformeres han demostrado ser muy efectivos.
#
# ### Desafíos:
#
# 1.  **Escalabilidad computacional:** Los modelos de Transformeres tienen una gran complejidad computacional debido a sus muchas capas y nodos, lo que puede hacerlo dificultoso para la implementación en sistemas con recursos limitados.
# 2.  **Capacidad de entrenamiento:** El entrenamiento de los modelos de Transformere requiere grandes cantidades de datos y memoria de almacenamiento para almacenar los pesos del modelo durante el proceso de aprendizaje.
#
# En resumen, los modelos de Transformere han revolucionado las capacidades de procesamiento del lenguaje natural al permitir la atención no lineal sobre la secuencia de tokens. Estos avances están cambiando significativamente cómo se realizan tareas como traducción automática y generación de texto, pero siguen presentando retos en términos de escalabilidad computacional y capacidades de entrenamiento.
#
# Temperature=0.7:
# Los Transformers son un tipo de modelo de red neuronal recurrente (RNN) que han revolucionado el campo del procesamiento de lenguaje natural (PLN). Introducidos por Vaswani et al. en 2017, los Transformers han demostrado ser una herramienta fundamental en la automatización de tareas lingüísticas como traducciones, clasificación de texto, resumen y generación de texto.
#
# **Características clave**
#
# 1.  **Arquitectura**: La arquitectura de los Transformers se basa en un mecanismo llamado "Atención" que permite al modelo procesar secuencias de lenguaje de manera simultánea.
# 2.  **Autoatención**: Los Transformers permiten a las capas de atención auto-atentar entre sí, lo que les permite capturar relaciones más complejas en el texto.
# 3.  **Escalabilidad**: La arquitectura de los Transformers es escalable y puede procesar secuencias de lenguaje largas.
#
# **Ventajas**
#
# 1.  **Mejora en rendimiento**: Los Transformers han demostrado mejorar significativamente la precisión en tareas como clasificación de texto, traducciones y generación de texto.
# 2.  **Flexibilidad**: La arquitectura de los Transformers permite a los modelos procesar diferentes tamaños de entrada y diferentes tipos de tarea.
# 3.  **Desempeño en aplicaciones**: Los Transformers han sido utilizados en una variedad de aplicaciones, desde chatbots hasta sistemas de recomendación.
#
# **Limitaciones**
#
# 1.  **Requieren grandes cantidades de datos**: Los Transformers requieren de grandes cantidades de datos para entrenarse.
# 2.  **Son costosos de entrenar**: Los Transformers son modelos complejos que requieren un gran número de recursos computacionales y memoria.
# 3.  **Pueden ser difíciles de interpretar**: A diferencia de otros modelos, los Transformers pueden ser difíciles de interpretar debido a la complejidad de su arquitectura.
#
# En resumen, los Transformers son una herramienta fundamental en el procesamiento de lenguaje natural que ha revolucionado el campo al permitir la automatización de tareas lingüísticas con alta precisión. Sin embargo, también presentan algunas limitaciones que deben ser consideradas a la hora de su implementación.
#
# Temperature=1.0:
# Los Transformers son un tipo de arquitectura neuronal utilizada ampliamente en el campo del Procesamiento de Lenguaje Natural (PLN). Fueron presentados originalmente por la investigación "Attention is All You Need" en 2017, y desde entonces han tenido una impacto significativo en la capacidad de las máquinas para comprender y generar lenguaje.
#
# **Ventajas clave de los Transformers:**
#
# 1.  **Atención a nivel de token**: Los Transformers permiten que el modelo atienda directamente a cada token (palabra, símbolo o caracter) del input, lo que facilita la captura de relaciones entre ellos.
# 2.  **No requieren secuencias lineales**: En lugar de recorrer las secuencias en orden cronológico, los Transformers pueden procesarlas de manera paralela y simultánea gracias a su uso de módulos autoregresivos de atención (self-attention).
# 3.  **Atención jerárquica**: Se puede utilizar múltiples capas de self-atención para capturar relaciones a diferentes niveles de abstracción.
#
# **Aplicaciones de los Transformers en el PLN:**
#
# 1.  **Traducción automática**: Los Transformers han mejorado significativamente la precisión y fluidez en las traducciones automatizadas.
# 2.  **Clasificación de texto**: Son útiles para clasificar textos, identificando temas, sentimientos o categorías relevantes.
# 3.  **Generación de texto**: Capaces de generar texto coherente e informativo a partir de un conjunto de inputs.
# 4.  **Comprensión del lenguaje**: Ayudan en la comprensión del significado y el contexto de los textos.
#
# **Desafíos y posibles mejoras:**
#
# 1.  **Eficacia computacional**: Los Transformers pueden requerir recursos computacionales significativos para procesar grandes secuencias de texto.
# 2.  **Capacidad de almacenamiento de memoria**: Es importante seleccionar una configuración que equilibre el desempeño con las limitaciones de memoria.
#
# En conclusión, los Transformers han revolucionado el campo del PLN al proporcionar modelos más efectivos y eficientes para comprender y procesar lenguaje humano.

# %% [markdown]
# ---
#
# ### 4.3 Probar streaming de resultados

# %%
import json

payload = {
    "model": "llama3",
    "prompt": "Nombra tres aplicaciones prácticas de los LLMs en empresas.",
    "stream": True
}
response = requests.post(f"{OLLAMA_HOST}/api/generate", json=payload, stream=True)
print("Respuesta en streaming:")
for line in response.iter_lines():
    if line:
        chunk = json.loads(line)
        print(chunk.get("response", ""), end="", flush=True)
        if chunk.get("done"):
            print("\n--- Generación completada ---")

# %% [markdown]
# ---
#
# ## 5. Manejo básico de errores en la API

# %%
try:
    payload = {
        "model": "llama3",
        "prompt": "¿Cuál es el futuro de la IA?",
        "stream": False
    }
    response = requests.post(f"{OLLAMA_HOST}/api/generate", json=payload, timeout=40)
    response.raise_for_status()
    print(response.json().get("response", ""))
except requests.exceptions.ConnectionError:
    print("Error: Ollama no está corriendo en localhost:11434")
except Exception as e:
    print("Error inesperado:", e)
# Out:
# Error inesperado: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=40)

# %% [markdown]
# ---
#
# ## 6. (Opcional) Mini servidor Flask para consumir Ollama desde web
#
# **Ejecuta este script por separado si tienes Flask instalado**

# %%
# Guardar como app.py y ejecutar con: python app.py
from flask import Flask, request, jsonify
import requests

OLLAMA_HOST = "http://localhost:11434"

app = Flask(__name__)

@app.route('/genera', methods=['POST'])
def genera():
    datos = request.json
    prompt = datos.get("prompt", "")
    payload = {
        "model": "llama3.1",
        "prompt": prompt,
        "stream": False
    }
    resp = requests.post(f"{OLLAMA_HOST}/api/generate", json=payload)
    return jsonify(resp.json())

if __name__ == "__main__":
    app.run(port=5000, debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %% [markdown]
# ---
#
# ## 7. Preguntas y ejercicios de reflexión
#
# 1. **¿Qué diferencias observas en las respuestas del modelo cuando cambias el parámetro `temperature`?**
# 2. **¿Cómo podrías integrar Ollama en una aplicación real de atención al cliente?**
# 3. **¿Qué limitaciones encontraste usando la API REST de Ollama?**
# 4. **Prueba agregar un endpoint extra en Flask que realice streaming de la respuesta (requiere manejo avanzado de streams en Flask).**
#
# ---
#
# **¡Fin del laboratorio!**
